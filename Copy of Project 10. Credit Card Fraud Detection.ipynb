# %% [markdown]
# Importing the Dependencies

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
# loading the dataset to a Pandas DataFrame
credit_card_data = pd.read_csv('/content/creditcard.csv')

# %%
# first 5 rows of the dataset
credit_card_data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0     0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1     0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2     1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3     1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4     2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62    0.0
# 1  0.125895 -0.008983  0.014724    2.69    0.0
# 2 -0.139097 -0.055353 -0.059752  378.66    0.0
# 3 -0.221929  0.062723  0.061458  123.50    0.0
# 4  0.502292  0.219422  0.215153   69.99    0.0
#
# [5 rows x 31 columns]

# %%
credit_card_data.tail()
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 43659  41598 -0.538686 -0.635328 -0.041569 -3.022158  0.771776  3.556774
# 43660  41599 -0.349615 -2.860571  0.297766  0.801212 -1.523995  1.164260
# 43661  41599 -3.001222  2.899766  0.726874 -0.729992 -0.312792 -0.735557
# 43662  41599  1.042342 -0.390001 -0.463680 -1.737393  0.450611  0.604354
# 43663  41600  1.193909  0.067328  0.609239  0.825453 -0.332038 -0.101522
#
#              V7        V8        V9  ...       V21       V22       V23  \
# 43659 -1.418820  1.371999 -2.475053  ... -0.090409 -0.310254  0.168510
# 43660  0.037484  0.325220  0.862825  ...  0.315370 -0.503099 -0.514747
# 43661  0.960944 -0.276141  2.128747  ... -0.645540 -0.613956  0.111663
# 43662  0.068099  0.278030  0.555053  ... -0.137137 -0.286887  0.143336
# 43663 -0.130782 -0.033697  0.424588  ... -0.049950  0.213908 -0.068750
#
#             V24       V25       V26       V27       V28  Amount  Class
# 43659  0.955413 -0.427495 -0.375891  0.051010  0.072416   60.01    0.0
# 43660 -0.193890 -0.327091  0.875820 -0.144908  0.125368  745.56    0.0
# 43661  0.338567  0.268357  0.076981  1.184716  0.491066    8.99    0.0
# 43662 -0.986810  0.135599 -0.185344  0.035590 -0.008304   48.00    0.0
# 43663  0.182281  0.557841  0.400000       NaN       NaN     NaN    NaN
#
# [5 rows x 31 columns]

# %%
# dataset informations
credit_card_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43664 entries, 0 to 43663
# Data columns (total 31 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    43664 non-null  int64
#  1   V1      43664 non-null  float64
#  2   V2      43664 non-null  float64
#  3   V3      43664 non-null  float64
#  4   V4      43664 non-null  float64
#  5   V5      43664 non-null  float64
#  6   V6      43664 non-null  float64
#  7   V7      43664 non-null  float64
#  8   V8      43664 non-null  float64
#  9   V9      43664 non-null  float64
#  10  V10     43664 non-null  float64
#  11  V11     43664 non-null  float64
#  12  V12     43664 non-null  float64
#  13  V13     43664 non-null  float64
#  14  V14     43664 non-null  float64
#  15  V15     43664 non-null  float64
#  16  V16     43664 non-null  float64
#  17  V17     43664 non-null  float64
#  18  V18     43664 non-null  float64
#  19  V19     43664 non-null  float64
#  20  V20     43664 non-null  float64
#  21  V21     43664 non-null  float64
#  22  V22     43664 non-null  float64
#  23  V23     43664 non-null  float64
#  24  V24     43664 non-null  float64
#  25  V25     43664 non-null  float64
#  26  V26     43664 non-null  float64
#  27  V27     43663 non-null  float64
#  28  V28     43663 non-null  float64
#  29  Amount  43663 non-null  float64
#  30  Class   43663 non-null  float64
# dtypes: float64(30), int64(1)
# memory usage: 10.3 MB

# %%
# checking the number of missing values in each column
credit_card_data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       1
# V28       1
# Amount    1
# Class     1
# dtype: int64

# %%
# distribution of legit transactions & fraudulent transactions
credit_card_data['Class'].value_counts()
# Out:
# Class
# 0.0    43529
# 1.0      134
# Name: count, dtype: int64

# %% [markdown]
# This Dataset is highly unblanced

# %% [markdown]
# 0 --> Normal Transaction
#
# 1 --> fraudulent transaction

# %%
# separating the data for analysis
legit = credit_card_data[credit_card_data.Class == 0]
fraud = credit_card_data[credit_card_data.Class == 1]

# %%
print(legit.shape)
print(fraud.shape)
# Out:
# (43529, 31)
# (134, 31)

# %%
# statistical measures of the data
legit.Amount.describe()
# Out:
# count    43529.000000
# mean        90.302800
# std        238.465356
# min          0.000000
# 25%          7.580000
# 50%         24.900000
# 75%         81.400000
# max       7879.420000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count     134.000000
# mean       93.928433
# std       231.551248
# min         0.000000
# 25%         1.000000
# 50%         6.455000
# 75%        99.990000
# max      1809.680000
# Name: Amount, dtype: float64

# %%
# compare the values for both transactions
credit_card_data.groupby('Class').mean()
# Out:
#                Time        V1        V2         V3        V4        V5  \
# Class
# 0.0    26892.929610 -0.210136  0.014404   0.735522  0.173494 -0.226584
# 1.0    25259.246269 -7.759814  5.619386 -10.672832  6.111351 -5.776140
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0.0    0.106817 -0.092752  0.039222  0.185126  ...  0.046501 -0.029740
# 1.0   -2.360976 -8.192938  4.040000 -3.571525  ...  0.507150  0.931331
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0.0   -0.109589 -0.039132  0.010036  0.135999  0.022175  0.004776  0.004927
# 1.0   -0.270332 -0.315606 -0.096976  0.279383  0.168436  0.687503  0.063472
#
#           Amount
# Class
# 0.0    90.302800
# 1.0    93.928433
#
# [2 rows x 30 columns]

# %% [markdown]
# Under-Sampling

# %% [markdown]
# Build a sample dataset containing similar distribution of normal transactions and Fraudulent Transactions

# %% [markdown]
# Number of Fraudulent Transactions --> 492

# %%
legit_sample = legit.sample(n=492)

# %% [markdown]
# Concatenating two DataFrames

# %%
new_dataset = pd.concat([legit_sample, fraud], axis=0)

# %%
new_dataset.head()
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 8107   11023  1.247083  0.056050  0.887129  0.317918 -0.763141 -0.815825
# 42818  41259 -0.604464  1.165543  1.440265 -0.529180  0.308291 -0.916368
# 6770    8518  1.064551  0.289434  1.593828  3.074803 -0.936387 -0.238157
# 11249  19526 -0.587771  0.210109  2.101555  0.465729  0.368570  2.517161
# 17512  28781  1.482101 -0.207349 -0.375907 -0.783941 -0.277711 -1.090871
#
#              V7        V8        V9  ...       V21       V22       V23  \
# 8107  -0.385378 -0.245169  1.621717  ... -0.057813  0.130729 -0.024041
# 42818  0.823720 -1.124731 -0.207796  ...  0.532817 -0.835310  0.063913
# 6770  -0.514762  0.023807  1.384187  ... -0.046151  0.205643 -0.021948
# 11249 -0.472747  0.816629  1.303953  ...  0.067798  0.668968  0.172850
# 17512  0.054004 -0.455279 -1.318530  ...  0.173663  0.500749 -0.243198
#
#             V24       V25       V26       V27       V28  Amount  Class
# 8107   0.435909  0.232679  1.028124 -0.084526  0.007559   15.95    0.0
# 42818  0.304591 -0.474359 -0.156986 -0.047532 -0.064756    1.98    0.0
# 6770   0.854784  0.401331  0.079234 -0.005584  0.028435   22.74    0.0
# 11249 -1.363334 -0.990967  0.401930  0.199978  0.140381   51.98    0.0
# 17512 -0.035770  0.903519 -0.058424 -0.021074 -0.000085   15.00    0.0
#
# [5 rows x 31 columns]

# %%
new_dataset.tail()
# Out:
#         Time         V1        V2         V3        V4         V5        V6  \
# 43061  41353 -15.020981  8.075240 -16.298091  5.664820 -11.918153 -4.246957
# 43160  41397 -14.970346  8.401421 -16.867238  8.252334 -13.565130 -2.782438
# 43204  41413 -15.140450  7.378042 -16.356367  9.194935 -13.466163 -2.958431
# 43428  41505 -16.526507  8.584972 -18.649853  9.505594 -13.793819 -2.832404
# 43624  41582  -1.048005  1.300219  -0.180401  2.589843  -1.164794  0.031823
#
#               V7         V8        V9  ...       V21       V22       V23  \
# 43061 -14.716668   9.435084 -6.795398  ...  2.525115 -0.832074 -0.186117
# 43160 -14.263735   9.643419 -7.701499  ...  2.714045 -0.101355 -0.439666
# 43204 -16.165539  10.075254 -7.901821  ...  3.147428  0.341678 -1.150162
# 43428 -16.701694   7.517344 -8.507059  ...  1.190739 -1.127670 -2.358579
# 43624  -2.175778   0.699072 -1.140208  ...  0.549014  0.624321 -0.136663
#
#             V24       V25       V26       V27       V28  Amount  Class
# 43061  0.429781  0.697103  0.056031 -1.310888 -0.707403   34.12    1.0
# 43160  0.519514  0.789328  0.064357 -1.621386 -1.104819  273.01    1.0
# 43204  0.795190 -0.194542  0.145964 -2.458680 -1.189888  106.55    1.0
# 43428  0.673461 -1.413700 -0.462762 -2.018575 -1.042804  364.19    1.0
# 43624  0.131738  0.030921 -0.176701  0.504898  0.069882   39.45    1.0
#
# [5 rows x 31 columns]

# %%
new_dataset['Class'].value_counts()
# Out:
# Class
# 0.0    492
# 1.0    134
# Name: count, dtype: int64

# %%
new_dataset.groupby('Class').mean()
# Out:
#                Time        V1        V2         V3        V4        V5  \
# Class
# 0.0    27262.957317 -0.202391 -0.088538   0.740463  0.191960 -0.231593
# 1.0    25259.246269 -7.759814  5.619386 -10.672832  6.111351 -5.776140
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0.0    0.137884 -0.008537  0.067924  0.216413  ...  0.083603 -0.048542
# 1.0   -2.360976 -8.192938  4.040000 -3.571525  ...  0.507150  0.931331
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0.0   -0.054217 -0.096363 -0.002828  0.153043  0.000056  0.025279  0.007220
# 1.0   -0.270332 -0.315606 -0.096976  0.279383  0.168436  0.687503  0.063472
#
#            Amount
# Class
# 0.0    105.783232
# 1.0     93.928433
#
# [2 rows x 30 columns]

# %% [markdown]
# Splitting the data into Features & Targets

# %%
X = new_dataset.drop(columns='Class', axis=1)
Y = new_dataset['Class']

# %%
print(X)
# Out:
#         Time         V1        V2         V3        V4         V5        V6  \
# 8107   11023   1.247083  0.056050   0.887129  0.317918  -0.763141 -0.815825
# 42818  41259  -0.604464  1.165543   1.440265 -0.529180   0.308291 -0.916368
# 6770    8518   1.064551  0.289434   1.593828  3.074803  -0.936387 -0.238157
# 11249  19526  -0.587771  0.210109   2.101555  0.465729   0.368570  2.517161
# 17512  28781   1.482101 -0.207349  -0.375907 -0.783941  -0.277711 -1.090871
# ...      ...        ...       ...        ...       ...        ...       ...
# 43061  41353 -15.020981  8.075240 -16.298091  5.664820 -11.918153 -4.246957
# 43160  41397 -14.970346  8.401421 -16.867238  8.252334 -13.565130 -2.782438
# 43204  41413 -15.140450  7.378042 -16.356367  9.194935 -13.466163 -2.958431
# 43428  41505 -16.526507  8.584972 -18.649853  9.505594 -13.793819 -2.832404
# 43624  41582  -1.048005  1.300219  -0.180401  2.589843  -1.164794  0.031823
#
#               V7         V8        V9  ...       V20       V21       V22  \
# 8107   -0.385378  -0.245169  1.621717  ... -0.032185 -0.057813  0.130729
# 42818   0.823720  -1.124731 -0.207796  ... -0.250368  0.532817 -0.835310
# 6770   -0.514762   0.023807  1.384187  ... -0.241277 -0.046151  0.205643
# 11249  -0.472747   0.816629  1.303953  ... -0.009694  0.067798  0.668968
# 17512   0.054004  -0.455279 -1.318530  ...  0.168140  0.173663  0.500749
# ...          ...        ...       ...  ...       ...       ...       ...
# 43061 -14.716668   9.435084 -6.795398  ... -0.995787  2.525115 -0.832074
# 43160 -14.263735   9.643419 -7.701499  ... -1.614660  2.714045 -0.101355
# 43204 -16.165539  10.075254 -7.901821  ... -1.691482  3.147428  0.341678
# 43428 -16.701694   7.517344 -8.507059  ... -1.514923  1.190739 -1.127670
# 43624  -2.175778   0.699072 -1.140208  ...  0.644993  0.549014  0.624321
#
#             V23       V24       V25       V26       V27       V28  Amount
# 8107  -0.024041  0.435909  0.232679  1.028124 -0.084526  0.007559   15.95
# 42818  0.063913  0.304591 -0.474359 -0.156986 -0.047532 -0.064756    1.98
# 6770  -0.021948  0.854784  0.401331  0.079234 -0.005584  0.028435   22.74
# 11249  0.172850 -1.363334 -0.990967  0.401930  0.199978  0.140381   51.98
# 17512 -0.243198 -0.035770  0.903519 -0.058424 -0.021074 -0.000085   15.00
# ...         ...       ...       ...       ...       ...       ...     ...
# 43061 -0.186117  0.429781  0.697103  0.056031 -1.310888 -0.707403   34.12
# 43160 -0.439666  0.519514  0.789328  0.064357 -1.621386 -1.104819  273.01
# 43204 -1.150162  0.795190 -0.194542  0.145964 -2.458680 -1.189888  106.55
# 43428 -2.358579  0.673461 -1.413700 -0.462762 -2.018575 -1.042804  364.19
# 43624 -0.136663  0.131738  0.030921 -0.176701  0.504898  0.069882   39.45
#
# [626 rows x 30 columns]

# %%
print(Y)
# Out:
# 8107     0.0
# 42818    0.0
# 6770     0.0
# 11249    0.0
# 17512    0.0
#         ...
# 43061    1.0
# 43160    1.0
# 43204    1.0
# 43428    1.0
# 43624    1.0
# Name: Class, Length: 626, dtype: float64

# %% [markdown]
# Split the data into Training data & Testing Data

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, stratify=Y, random_state=2)

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (626, 30) (500, 30) (126, 30)

# %% [markdown]
# Model Training

# %% [markdown]
# Logistic Regression

# %%
model = LogisticRegression()

# %%
# training the Logistic Regression Model with Training Data
model.fit(X_train, Y_train)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %% [markdown]
# Model Evaluation

# %% [markdown]
# Accuracy Score

# %%
# accuracy on training data
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)

# %%
print('Accuracy on Training data : ', training_data_accuracy)
# Out:
# Accuracy on Training data :  0.976

# %%
# accuracy on test data
X_test_prediction = model.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, Y_test)

# %%
print('Accuracy score on Test Data : ', test_data_accuracy)
# Out:
# Accuracy score on Test Data :  0.9841269841269841

# %%
import joblib

# Save model and features
joblib.dump(model, "fraud_model.pkl")
joblib.dump(list(X.columns), "fraud_features.pkl")

print("✅ Model and features saved!")
# Out:
# ✅ Model and features saved!

# %%
# !pip install flask flask-ngrok joblib
# Out:
# Requirement already satisfied: flask in /usr/local/lib/python3.12/dist-packages (3.1.2)
# Collecting flask-ngrok
#   Downloading flask_ngrok-0.0.25-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (1.5.2)
# Requirement already satisfied: blinker>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from flask) (1.9.0)
# Requirement already satisfied: click>=8.1.3 in /usr/local/lib/python3.12/dist-packages (from flask) (8.2.1)
# Requirement already satisfied: itsdangerous>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from flask) (2.2.0)
# Requirement already satisfied: jinja2>=3.1.2 in /usr/local/lib/python3.12/dist-packages (from flask) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from flask) (3.0.2)
# Requirement already satisfied: werkzeug>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from flask) (3.1.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from flask-ngrok) (2.32.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->flask-ngrok) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->flask-ngrok) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->flask-ngrok) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->flask-ngrok) (2025.8.3)
# Downloading flask_ngrok-0.0.25-py3-none-any.whl (3.1 kB)
# Installing collected packages: flask-ngrok
# Successfully installed flask-ngrok-0.0.25

# %%
from flask import Flask, request, jsonify
import pandas as pd
import joblib

# Load model and feature list
model = joblib.load("fraud_model.pkl")
feature_cols = joblib.load("fraud_features.pkl")

app = Flask(__name__)

@app.route("/")
def home():
    return "✅ Fraud Detection API (Light Version) is running!"

@app.route("/predict", methods=["POST"])
def predict():
    data = request.get_json()

    # Convert input JSON → DataFrame
    df = pd.DataFrame([data], columns=feature_cols)

    pred = model.predict(df)[0]
    prob = model.predict_proba(df)[0][1]

    return jsonify({
        "prediction": int(pred),
        "probability_fraud": float(prob)
    })

if __name__ == "__main__":
    app.run(port=5000, debug=False, use_reloader=False)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# INFO:werkzeug:WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# INFO:werkzeug:Press CTRL+C to quit
# ERROR:root:Unexpected exception finding object shape
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/google/colab/_debugpy_repr.py", line 54, in get_shape
#     shape = getattr(obj, 'shape', None)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/werkzeug/local.py", line 318, in __get__
#     obj = instance._get_current_object()
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/werkzeug/local.py", line 519, in _get_current_object
#     raise RuntimeError(unbound_message) from None
# RuntimeError: Working outside of request context.
#
# This typically means that you attempted to use functionality that needed
# an active HTTP request. Consult the documentation on testing for
# information about how to avoid this problem.
# ERROR:root:Unexpected exception finding object shape
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/google/colab/_debugpy_repr.py", line 54, in get_shape
#     shape = getattr(obj, 'shape', None)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/werkzeug/local.py", line 318, in __get__
#     obj = instance._get_current_object()
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/werkzeug/local.py", line 519, in _get_current_object
#     raise RuntimeError(unbound_message) from None
# RuntimeError: Working outside of request context.
#
# This typically means that you attempted to use functionality that needed
# an active HTTP request. Consult the documentation on testing for
# information about how to avoid this problem.
# ERROR:root:Unexpected exception finding object shape
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/google/colab/_debugpy_repr.py", line 54, in get_shape
#     shape = getattr(obj, 'shape', None)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/werkzeug/local.py", line 318, in __get__
#     obj = instance._get_current_object()
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/werkzeug/local.py", line 519, in _get_current_object
#     raise RuntimeError(unbound_message) from None
# RuntimeError: Working outside of request context.
#
# This typically means that you attempted to use functionality that needed
# an active HTTP request. Consult the documentation on testing for
# information about how to avoid this problem.

# %%
import requests

# Test 1: Check if API is running
response = requests.get("http://127.0.0.1:5000/")
print("✅ API Status:", response.text)

# Test 2: Make a prediction (you need to provide actual feature values)
test_transaction = {
    # Add your actual feature names and sample values here
    # Example: "amount": 100.50, "merchant": "store123", etc.
}


prediction = requests.post("http://127.0.0.1:5000/predict", json=test_transaction)
print("🔍 Prediction:", prediction.json())

# %%
import joblib
features = joblib.load("fraud_features.pkl")
print("Number of features:", len(features))
print("\nFeature names:")
for i, feat in enumerate(features, 1):
    print(f"{i}. {feat}")
